# %% [markdown]
# <a href="https://colab.research.google.com/github/barissglc/VeriAnaliz-FeatureExtraction/blob/main/sagliktaVeriH2_odev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle datasets download -d ravindrasinghrana/job-description-dataset
# Out:
# ...
# 100% 456M/457M [00:13<00:00, 41.6MB/s]
# 100% 457M/457M [00:13<00:00, 36.2MB/s]

# %%
# !unzip job-description-dataset.zip
# Out:
# Archive:  job-description-dataset.zip
#   inflating: job_descriptions.csv

# %%
dataframe = pd.read_csv('job_descriptions.csv')

# %%
set(dataframe["location"])

# %%
#dataframe.loc[dataframe["location"]=="London"]

# %%
dataframe.loc[dataframe["Job Title"]=="Software Engineer"]
# Out:
#                    Job Id     Experience Qualifications Salary Range  \
# 23       2808730603865187  2 to 14 Years            PhD   $62K-$124K
# 303      3020706461775166   0 to 8 Years         M.Tech   $62K-$110K
# 333      1610592842191022  4 to 13 Years         M.Tech   $58K-$121K
# 420       161230026511942  3 to 10 Years            MCA    $64K-$98K
# 438        11389387326971  5 to 14 Years            BBA   $60K-$117K
# ...                   ...            ...            ...          ...
# 1615764  2146804100529038  1 to 13 Years         B.Tech   $59K-$116K
# 1615797  1880005290249441  4 to 12 Years            PhD   $65K-$113K
# 1615846   542248957868032   3 to 9 Years             BA    $64K-$98K
# 1615882   789253099307666  2 to 13 Years            MCA   $63K-$115K
# 1615915  2644082325448032  0 to 11 Years            PhD   $57K-$120K
#
#               location              Country  latitude  longitude  Work Type  \
# ...
