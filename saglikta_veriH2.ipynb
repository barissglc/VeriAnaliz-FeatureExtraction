# %% [markdown]
# <a href="https://colab.research.google.com/github/barissglc/VeriAnaliz-FeatureExtraction/blob/main/saglikta_veriH2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# python ile döngü falan olusturarak ödev yap. tablo verilerini göstererek collabta göstermek
import pandas as pd

def MyFunction(number):
  print("hello world " + str(number))


MyFunction(16)
# Out:
# hello world 16

# %%
class MyClass:
  def __init__(self):
    self.objectData=576

  def printObjectData(self):
    print(self.objectData)
    return self.objectData

# %%
Object1= MyClass()
print("Object1 veri üyesi:", Object1.objectData)

# MyClass örneğinin veri üyesini yazdırmak için fonksiyonu çağırın
Object1.printObjectData()
# Out:
# Object1 veri üyesi: 576
# 576
# 576

# %%
dataframe = pd.read_csv('footballData.csv')

# %%
dataframe.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     231747  https://sofifa.com/player/231747/kylian-mbappe...
# 7     192448  https://sofifa.com/player/192448/marc-andre-te...
# 8     203376  https://sofifa.com/player/203376/virgil-van-di...
# 9     212831  https://sofifa.com/player/212831/alisson-ramse...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  24/06/1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  05/02/1985
# ...

# %% [markdown]
# # ODEV

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv('spotify-2023.csv', sep=';', encoding='ISO-8859-1')

# %%
dataframe.head(10)
# Out:
#   track_name,artist(s)_name,artist_count,released_year,released_month,released_day,in_spotify_playlists,in_spotify_charts,streams,in_apple_playlists,in_apple_charts,in_deezer_playlists,in_deezer_charts,in_shazam_charts,bpm,key,mode,danceability_%,valence_%,energy_%,acousticness_%,instrumentalness_%,liveness_%,speechiness_%
# 0  Seven (feat. Latto) (Explicit Ver.),"Latto, Ju...
# 1  LALA,Myke Towers,1,2023,3,23,1474,48,133716286...
# 2  vampire,Olivia Rodrigo,1,2023,6,30,1397,113,14...
# 3  Cruel Summer,Taylor Swift,1,2019,8,23,7858,100...
# 4  WHERE SHE GOES,Bad Bunny,1,2023,5,18,3133,50,3...
# 5  Sprinter,"Dave, Central Cee",2,2023,6,1,2186,9...
# 6  Ella Baila Sola,"Eslabon Armado, Peso Pluma",2...
# 7  Columbia,Quevedo,1,2023,7,7,714,43,58149378,25...
# 8  fukumean,Gunna,1,2023,5,15,1096,83,95217315,60...
# 9  La Bebe - Remix,"Peso Pluma, Yng Lvcas",2,2023...
# No charts were generated by quickchart
